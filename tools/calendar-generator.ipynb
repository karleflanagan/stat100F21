# %%
import pandas as pd
import datetime

# start, end, week_topics, prelectures, surveys, homeworks, general, conflicts, and exams ...
# ... are the only things that need to be updated.
# After making changes to these variables, run all code blocks.
# Once "pyperclip.copy(doc)" is run, head over to "calendar.html" in the "_includes" folder and ...
# ... select and remove all of the existing text, and then paste - you will see a new, full body ...
# ... of html code for the calendar.

# Note: Pyperclip will need to be installed on the computer in order to use. Head to ...
# ... https://pypi.org/project/pyperclip/ 
# Or type: "pip install pyperclip" into terminal.

# Enter first day of class and last day of finals.
# these dates will be automatically expanded to the first Monday and Last Friday ...
# ... (if given dates are not the first monday or last friday respectively). 
# This makes full weeks for the beginning and end of calendar.
start = '2023-01-16'
end = '2023-05-12'

# week_topics does not come with automatic bold formating. However, the line spacing below bolded elements are automatic.
# All values in prelectures, surveys, homeworks, general, conflicts, and exams dictionaries are automatically formatted.
week_topics = {
    1: "<b>Week 1: Chapter 1</b>(Controlled Experiments)",
    2: "<b>Week 2: Chapters 2-3</b>(Observational Studies)",
    3: "<b>Week 3: Chapters 3-5</b>(Histograms, Avg, Median, SD, & Normal Curve)",
    4: "<b>Week 4: Exam Week</b>",
    5: "<b>Week 5: Chapters 6-7</b>(Boxplots & Correlation)",
    6: "<b>Week 6: Chapters 8-10</b>(Regression & RMSE)",
    7: "<b>Week 7: Chapters 11-12</b>(Probability)",
    8: "<b>Week 8: Exam Week</b>",
    9: "<b>Week 9: Spring Break</b>",
    10: "<b>Week 10: Chapters 13-15</b>(EV, SE, & Random Variables)",
    11: "<b>Week 11: Chapters 15-16</b>(Box Models & Probability Histograms)",
    12: "<b>Week 12: Chapters 17-19</b>(Sampling & Inference)",
    13: "<b>Week 13: Exam Week</b>",
    14: "<b>Week 14: Chapters 20-22</b>(Hypothesis Testing: Z & t Tests)",
    15: "<b>Week 15: Chapters 22-24</b>(Hypothesis Testing: Chi Square Tests)",
    16: "<b>Week 16: Last Week of Class</b>(Final Exam Review)",
    17: "<b>Week 17: Finals Week</b>"

    #1: "<b>Week 1: Chapter 1</b>(Controlled Experiments)",
    #2: "<b>Week 2: Chapters 2-3</b>(Observational Studies)",
    #3: "<b>Week 3: Chapters 3-5</b>(Histograms, Avg, Median, SD, & Normal Curve)",
    #4: "<b>Week 4: Exam Week</b>",
    #5: "<b>Week 5: Chapters 6-7</b>(Boxplots & Correlation)",
    #6: "<b>Week 6: Chapters 8-10</b>(Regression & RMSE)",
    #7: "<b>Week 7: Chapters 11-12</b>(Probability)",
    #8: "<b>Week 8: Exam Week</b>",
    #9: "<b>Week 9: Chapters 13-15</b>(EV, SE, & Random Variables)",
    #10: "<b>Week 10: Chapters 15-16</b>(Box Models & Probability Histograms)",
    #11: "<b>Week 11: Chapters 17-19</b>(Sampling & Inference)",
    #12: "<b>Week 12: Exam Week</b>",
    #13: "<b>Week 13: Chapters 20-22</b>(Hypothesis Testing: Z & t Tests)",
    #14: "<b>Week 14: Fall Break</b>",
    #15: "<b>Week 15: Chapters 22-24</b>(Hypothesis Testing: Chi Square Tests)",
    #16: "<b>Week 16: Last Week of Class</b>(Final Exam Review)",
    #17: "<b>Week 16: Finals Week</b>"
}

prelectures = {
    '2023-01-20': 'Chapter 1 Prelecture Due',
    '2022-08-31': 'Chapter 2 Part 1 Prelecture Due',
    '2022-09-02': 'Chapter 2 Part 2 Prelecture Due',
    '2022-09-07': 'Chapter 3 Prelecture Due',
    '2022-09-09': 'Chapter 4 Prelecture Due',
    '2022-09-12': 'Chapter 5 Prelecture Due',
    '2022-09-23': 'Chapter 7 Prelecture Due',
    '2022-09-28': 'Chapter 8 Prelecture Due',
    '2022-09-30': 'Chapter 9 Prelecture Due',
    '2022-10-03': 'Chapter 10 Prelecture Due',
    '2022-10-05': 'Chapter 11 Prelecture Due',
    '2022-10-07': 'Chapter 12 Prelecture Due',
    '2022-10-19': 'Chapter 13 Prelecture Due',
    '2022-10-21': 'Chapter 14 Prelecture Due',
    '2022-10-24': 'Chapter 15 Prelecture Due',
    '2022-10-28': 'Chapter 16 Prelecture Due',
    '2022-11-02': 'Chapter 17 Prelecture Due',
    '2022-11-04': 'Chapter 18 Prelecture Due',
    '2022-11-18': 'Chapter 20 Prelecture Due',
    '2022-11-30': 'Chapter 21 Prelecture Due',
    '2022-12-02': 'Chapter 22 Prelecture Due',
    '2022-12-05': 'Chapter 23 Part 1 Prelecture Due',
    '2022-12-07': 'Chapter 23 Part 2 Prelecture Due'
}
surveys = {
    '2023-01-20': 'Bonus Survey 1 Due',
    '2023-02-03': 'Bonus Survey 2 Due',
    '2023-03-03': 'Bonus Survey 3 Due',
    '2023-04-07': 'Bonus Survey 4 Due',
    '2023-05-04': 'Bonus Survey 5 Due'
}

research = {
    # Research Opportunities
    # '2022-08-27': 'Research Opportunity #1',
    # '2022-09-06': 'Research Opportunity #2',
    # '2022-09-27': 'Research Opportunity #3',
    # '2022-10-11': 'Research Opportunity #4'
}

homeworks = {
    '2022-08-30': 'HW Assignment 1 Due',
    '2022-09-01': 'HW Assignment 2 Due',
    '2022-09-06': 'HW Assignment 3 Due',
    '2022-09-08': 'HW Assignment 4 Due',
    '2022-09-13': 'HW Assignment 5 Due',
    '2022-09-22': 'HW Assignment 6 Due',
    '2022-09-27': 'HW Assignment 7 Due',
    '2022-09-29': 'HW Assignment 8 Due',
    '2022-10-04': 'HW Assignment 9 Due',
    '2022-10-06': 'HW Assignment 10 Due',
    '2022-10-11': 'HW Assignment 11 Due',
    '2022-10-20': 'HW Assignment 12 Due',
    '2022-10-25': 'HW Assignment 13 Due',
    '2022-10-27': 'HW Assignment 14 Due',
    '2022-11-01': 'HW Assignment 15 Due',
    '2022-11-03': 'HW Assignment 16 Due',
    '2022-11-08': 'HW Assignment 17 Due',
    '2022-11-17': 'HW Assignment 18 Due',
    '2022-11-29': 'HW Assignment 19 Due',
    '2022-12-01': 'HW Assignment 20 Due',
    '2022-12-06': 'HW Assignment 21 Due',
    '2022-12-08': 'HW Assignment 22 Due'
}

holidays = {
#     Spring Holidays
    '2023-01-16': 'Martin Luther King Jr. Day',
    '2023-02-14': "Valentine's Day &#128152;",
    '2023-02-20': "President's Day",
    '2022-05-13': '<b>SUMMER BREAK!!! <a href="{{ site.data.info.rickroll }}">&#127796;</a> </b>Have a wonderful break!',
    '2022-04-01': '<a href="https://www.youtube.com/watch?v=QtBDL8EiNZo">Exam 3 Answers!</a>',
#     Fall Holidays
    '2022-09-05': 'Labor Day <a href="{{ site.data.info.rickroll }}">&#128296;</a>',	
    '2022-10-31': "Halloween &#127875;",
    '2022-11-01': "Day of the Dead &#128128;",
    '2022-11-11': "Veteran's Day",
    '2022-11-08': 'Election Day'
}

general = {
    '2022-12-17': '<b>WINTER BREAK!!! <a href="{{ site.data.info.rickroll }}">&#9924;</a> </b><br>Have a wonderful break!',
#     Break
    '2023-03-13': '---',
    '2023-03-14': '---',
    # '2022-11-23': 'FALL BREAK <a href="{{ site.data.info.rickroll }}">&#127810;</a>',
    '2023-03-15': 'SPRING BREAK <a href="{{ site.data.info.rickroll }}">&#127799;</a>',
    '2023-03-16': '---',
    '2023-03-17': '---',
#     Other
    '2022-09-08': 'Lecture: Online',
    '2022-09-10': 'Lecture: Online',
    '2022-09-15': 'No Classes! <a href="{{ site.data.info.rickroll }}">&#128522;</a>',
    '2022-03-10': 'No Classes! <a href="{{ site.data.info.rickroll }}">&#128522;</a>',
    '2022-04-14': 'No Classes! <a href="{{ site.data.info.rickroll }}">&#128522;</a>',
    '2022-01-18': 'First Day of Classes! <a href="{{ site.data.info.rickroll }}">&#128522;</a>',
    '2022-05-04': 'Last Day of Classes! <a href="{{ site.data.info.rickroll }}">&#128522;</a>',
    '2022-05-05': '<b>Reading Day</b>'
}
conflicts = {
    '2022-09-12': 'Exam 1 Conflict Sign-Up Due',
    '2022-10-10': 'Exam 2 Conflict Sign-Up Due',
    '2022-11-07': 'Exam 3 Conflict Sign-Up Due'
}
exams = {
    '2023-02-08': 'Exam 1 at 7pm',
    '2023-03-08': 'Exam 2 at 7pm',
    '2023-04-12': 'Exam 3 at 7pm',
    '2023-05-12': 'In Person Section L2 Final Exam from 1:30-4:30pm',
    # '2022-12-14': 'Online Section Final Exam from 1:30-4:30pm (to be taken in person)'
}
twitch = {
    # '2022-09-13': 'Exam 1 Twitch Review at 6pm',
    # '2022-10-11': 'Exam 2 Twitch Review at 6pm',
    # '2022-11-08': 'Exam 3 Twitch Review at 6pm',
    # '2022-12-10': 'Final Exam Twitch Review at 5-7pm'
}

# %%
start = datetime.datetime.strptime(start, '%Y-%m-%d')
print("start: " + str(start.date()) + " (" + start.strftime("%a") + ")")
end = datetime.datetime.strptime(end, '%Y-%m-%d')
print("end: " + str(end.date()) + " (" + end.strftime("%a") + ")")

while start.weekday() != 0:
    start += datetime.timedelta(-1)
print("extended start: " + str(start.date()) + " (" + start.strftime("%a") + ")")
while end.weekday() != 4:
    end += datetime.timedelta(1)
print("extended end: " + str(end.date()) + " (" + end.strftime("%a") + ")")
# Out:
# start: 2023-01-16 (Mon)
# end: 2023-05-12 (Fri)
# extended start: 2023-01-16 (Mon)
# extended end: 2023-05-12 (Fri)

# %%
dtrange = pd.date_range(start = start, end = end, freq = 'B')

cal = pd.DataFrame(dtrange)

cal.insert(1, 'month', dtrange.strftime("%B"))
cal.insert(2, 'day', dtrange.strftime("%a"))

week = []
for i in range(0,cal.shape[0]):
    week.append(int(i/5)+1)

cal.insert(3, 'week', pd.Series(week))

l = []
for week in range(1, cal['week'].nunique()+1):
    l.append(cal[cal['week'] == week]['month'].mode()[0])
    
block = []
for week in cal['week']:
    block.append(l[week-1])

cal.insert(4, 'block', pd.Series(block))

# def print_full(x):
#     pd.set_option('display.max_rows', len(x))
#     print(x)
#     pd.reset_option('display.max_rows')

# print(cal.shape)
# print_full(cal)

# %%
# 6 categories to check
# Priority levels:
#     1. Exams
#     2. Conflicts
#     3. Homeworks
#     4. Prelectures
#     5. Surveys
#     6. General

doc = '<div class="table-responsive">\n'
head = ('<tr>\n'+
        '  <th>Week</th>\n'+
        '  <th>Mon</th>\n'+
        '  <th>Tues</th>\n'+
        '  <th>Wed</th>\n'+
        '  <th>Thurs</th>\n'+
        '  <th>Fri</th>\n'+
        '</tr>')

for block in cal['block'].value_counts()[cal['block'].unique()].index.tolist():
#     print('<h1>' + block + '</h1>')
    doc += '<h3 style="text-align: center;">' + block + '</h3>'
    doc += '\n<div class="heading-underline"></div>'
    doc +=  '\n<table class="table table-bordered">'
#     print(head)
    doc += '\n' + head + '\n'
    sub1 = cal[cal['block'] == block]
    for week in sub1['week'].value_counts()[sub1['week'].unique()].index.tolist():
        sub2 = sub1[sub1['week'] == week]
        date = ''
        content = ''
        date += '<tr>\n  <td style="line-height:1px;margin:0;"></td>'
        content += '\n<tr>' + '\n  <td>' + str(week_topics.get(week)) + '</td>'
        for day in sub2[0]:
            events = []
            date += '\n  <td><p class="date">' + str(day.strftime("%d")) + '</p></td>'
            if (exams.get(str(day.date())) != None):
                events.append('<b><p class="exam">' + exams.get(str(day.date())) + '</p></b>')
            if (twitch.get(str(day.date())) != None):
                events.append('<b><p class="twitch">' + twitch.get(str(day.date())) + '</p></b>')
            if (conflicts.get(str(day.date())) != None):
                events.append('<b><p class="conf">' + conflicts.get(str(day.date())) + '</p></b>')
            if (homeworks.get(str(day.date())) != None):
                events.append('<p class="hw">' + homeworks.get(str(day.date())) + '</p>')
            if (prelectures.get(str(day.date())) != None):
                events.append('<p class="prel">' + prelectures.get(str(day.date())) + '</p>')
            if (surveys.get(str(day.date())) != None):
                events.append('<p class="surv">' + surveys.get(str(day.date())) + '</p>')
            if (research.get(str(day.date())) != None):
                events.append('<p class="surv">' + research.get(str(day.date())) + '</p>')
            if (general.get(str(day.date())) != None):
                events.append('<p>' + general.get(str(day.date())) + '</p>')
            if (holidays.get(str(day.date())) != None):
                events.append('<p>' + holidays.get(str(day.date())) + '</p>')
            if len(events) > 1:
                content += '\n  <td>'
                n=0
                for event in events:
                    content += event
                content += '</td>'
            elif len(events) == 1:
                content += '\n  <td>' + events[0] + '</td>'
            elif len(events) == 0:
                content += '\n  <td></td>'
        content += '\n</tr>'
        date += '\n</tr>'
        doc += date + content
        doc += '\n'
#         print(date, content)
#     print('\n')
    doc += '</table>\n\n'
doc += '</div>'
# print(doc)

# %%
# pyperclip is needed for easier copy to clipboard
# pip install pyperclip
import pyperclip
pyperclip.copy(doc)
